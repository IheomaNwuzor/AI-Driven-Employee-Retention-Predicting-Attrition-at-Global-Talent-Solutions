# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Load the dataset

# %%
data = pd.read_csv("employee_attrition.csv")

# %%
# Display the first few rows
data.head()
# Out:
#    EmployeeID   Age  Gender Department  MonthlyIncome  YearsAtCompany  \
# 0           1  38.0    Male         HR       0.000000            0.40
# 1           2  33.0    Male         HR       0.075385            0.25
# 2           3  40.0  Female      Sales       0.136375            0.70
# 3           4  47.0    Male         HR       0.174409            0.60
# 4           5  33.0  Female         IT       0.153290            0.20
#
#   OverTime  JobSatisfaction  WorkLifeBalance  TrainingTimesLastYear Attrition
# 0       No              2.0                3                    0.5        No
# 1       No              2.0                2                    0.3        No
# 2       No              1.0                2                    0.5        No
# 3       No              3.0                3                    0.2        No
# 4       No              NaN                3                    0.1       Yes

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8400 entries, 0 to 8399
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   EmployeeID             8400 non-null   int64
#  1   Age                    7561 non-null   float64
#  2   Gender                 8400 non-null   object
#  3   Department             8400 non-null   object
#  4   MonthlyIncome          7556 non-null   float64
#  5   YearsAtCompany         8400 non-null   float64
#  6   OverTime               8400 non-null   object
#  7   JobSatisfaction        7567 non-null   float64
#  8   WorkLifeBalance        8400 non-null   int64
#  9   TrainingTimesLastYear  8400 non-null   float64
#  10  Attrition              8400 non-null   object
# dtypes: float64(5), int64(2), object(4)
# memory usage: 722.0+ KB

# %%
data.describe()
# Out:
#         EmployeeID          Age  MonthlyIncome  YearsAtCompany  \
# count  8400.000000  7561.000000    7556.000000     8400.000000
# mean   3994.265952    34.657849       0.191155        0.296810
# std    2311.555446     7.633779       0.157068        0.204295
# min       1.000000    22.000000       0.000000        0.000000
# 25%    1987.750000    29.000000       0.062035        0.150000
# 50%    3990.500000    34.000000       0.167131        0.300000
# 75%    6002.000000    40.000000       0.288324        0.450000
# max    8000.000000    60.000000       1.000000        1.000000
#
#        JobSatisfaction  WorkLifeBalance  TrainingTimesLastYear
# count      7567.000000      8400.000000            8400.000000
# mean          2.189771         2.543690               0.226202
# std           1.015183         0.982885               0.148470
# min           1.000000         1.000000               0.000000
# 25%           1.000000         2.000000               0.100000
# 50%           2.000000         3.000000               0.200000
# 75%           3.000000         3.000000               0.300000
# max           4.000000         4.000000               1.000000

# %% [markdown]
# ### Remove irrelevant features

# %%
data.drop("EmployeeID", axis=1, inplace=True)

# %% [markdown]
# #### Handle Missing Values
# In this step, we check for missing values and decide on an appropriate imputation or removal strategy.

# %%
data.isnull().sum()
# Out:
# Age                      839
# Gender                     0
# Department                 0
# MonthlyIncome            844
# YearsAtCompany             0
# OverTime                   0
# JobSatisfaction          833
# WorkLifeBalance            0
# TrainingTimesLastYear      0
# Attrition                  0
# dtype: int64

# %%
# In percentage
data.isnull().mean()*100
# Out:
# Age                       9.988095
# Gender                    0.000000
# Department                0.000000
# MonthlyIncome            10.047619
# YearsAtCompany            0.000000
# OverTime                  0.000000
# JobSatisfaction           9.916667
# WorkLifeBalance           0.000000
# TrainingTimesLastYear     0.000000
# Attrition                 0.000000
# dtype: float64

# %% [markdown]
# #### Lets visualize the missing values for easy communications with HR/Stakeholders

# %%
import missingno as msno

msno.bar(data, color='sandybrown')
# Out:
# <Axes: >

# %%
# Display columns with missing values
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# #### Imputation Strategies
# **Numerical Columns:**
# - Use `mean`, `median`, or `mode` to impute.
# - For features like `Age`, median is often more robust against outliers.
#
# **Categorical Columns:**
# - Impute with the mode or create a new category (e.g., "Unknown").
#
# **Advanced Options:**
# - Use K-Nearest Neighbors (KNN) Imputation or regression models for more accurate imputation.

# %%
# Impute missing numerical values with median
data['Age'] = data['Age'].fillna(data['Age'].median())
data['MonthlyIncome'] = data['MonthlyIncome'].fillna(data['MonthlyIncome'].median())

# %%
# Impute missing categorical values with mode
data['JobSatisfaction'] = data['JobSatisfaction'].fillna(data['JobSatisfaction'].mode()[0])

# %% [markdown]
# ### Handling Duplicate Data
# Detect Duplicates

# %%
# Check for duplicate rows
data.duplicated().sum()
# Out:
# 408

# %% [markdown]
# ### Remove Duplicates
# - Duplicates can often be dropped unless there’s a need to retain them for specific analysis.

# %%
# Remove duplicate rows
data = data.drop_duplicates().reset_index(drop=True)

# %% [markdown]
# ### Handle Outliers
# Check for outliers in numerical columns.<br>
# Lets investigate the numerical columns for outliers by visualizing their distributions on histplot

# %%
numerical_columns = data.select_dtypes(include="number")
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(20, 20))
ax=ax.flatten()
for idx, col in enumerate(numerical_columns):
    sns.histplot(data[col], ax=ax[idx])
    ax[idx].set_title(f"Histplot for {col}")
plt.show()

# %% [markdown]
# #### We can use Boxplot to further confirm the outliers in numerical columns

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(20, 20))
ax=ax.flatten()
for idx, col in enumerate(numerical_columns):
    sns.boxplot(data[col], ax=ax[idx])
    ax[idx].set_title(f"Boxplot for {col}")
plt.show()

# %% [markdown]
# ### Lets remove the outliers on affected columns using IQR

# %%
affected_column = ["Age", "MonthlyIncome", "YearsAtCompany", "TrainingTimesLastYear"]

# %%
q1 = data[affected_column].quantile(0.25)
q3 = data[affected_column].quantile(0.75)

# %%
iqr = q3 - q1

# %%
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)

# %%
data[affected_column] = data[affected_column].clip(lower=lower_bound, upper=upper_bound, axis=1)

# %% [markdown]
# ### Lets verify that our data is now outlier free

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(20, 20))
ax=ax.flatten()
for idx, col in enumerate(numerical_columns):
    sns.boxplot(data[col], ax=ax[idx])
    ax[idx].set_title(f"Boxplot for {col}")
plt.show()

# %% [markdown]
# ### Encode Categorical Variables
# Convert categorical variables like `Gender`, `Department`, and `OverTime` into numeric formats.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# Label encoding for binary categories
label_enc = LabelEncoder()
data['Gender'] = label_enc.fit_transform(data['Gender'])  
data['OverTime'] = label_enc.fit_transform(data['OverTime'])
data['Attrition'] = label_enc.fit_transform(data['Attrition'])

# %%
# # One-hot encoding for multi-class categorical variables
data = pd.get_dummies(data, columns=['Department'], drop_first=True)

# %%
# Display the transformed dataset
data.head()
# Out:
#     Age  Gender  MonthlyIncome  YearsAtCompany  OverTime  JobSatisfaction  \
# 0  38.0       1       0.000000            0.40         0              2.0
# 1  33.0       1       0.075385            0.25         0              2.0
# 2  40.0       0       0.136375            0.70         0              1.0
# 3  47.0       1       0.174409            0.60         0              3.0
# 4  33.0       0       0.153290            0.20         0              1.0
#
#    WorkLifeBalance  TrainingTimesLastYear  Attrition  Department_HR  \
# 0                3                    0.5          0              1
# 1                2                    0.3          0              1
# 2                2                    0.5          0              0
# 3                3                    0.2          0              1
# 4                3                    0.1          1              0
#
#    Department_IT  Department_Operations  Department_Sales
# 0              0                      0                 0
# 1              0                      0                 0
# 2              0                      0                 1
# 3              0                      0                 0
# 4              1                      0                 0

# %% [markdown]
# ### Scale Numerical Features
# Scale numerical columns to bring them to a similar range, which can improve model performance.

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
scaler = StandardScaler()
num_cols_to_scale = ['Age', 'MonthlyIncome', 'YearsAtCompany', 'TrainingTimesLastYear']
data[num_cols_to_scale] = scaler.fit_transform(data[num_cols_to_scale])

# %%
# Verify scaling
data[num_cols_to_scale].describe()
# Out:
#                 Age  MonthlyIncome  YearsAtCompany  TrainingTimesLastYear
# count  7.992000e+03   7.992000e+03    7.992000e+03           7.992000e+03
# mean   1.013537e-16  -1.049100e-16    2.471608e-16          -6.579099e-17
# std    1.000063e+00   1.000063e+00    1.000063e+00           1.000063e+00
# min   -1.761989e+00  -1.301722e+00   -1.459421e+00          -1.552877e+00
# 25%   -6.414110e-01  -7.683502e-01   -7.232007e-01          -8.622104e-01
# 50%   -8.112171e-02  -1.424711e-01    1.301958e-02          -1.715433e-01
# 75%    6.192399e-01   5.819226e-01    7.492399e-01           5.191238e-01
# max    2.510216e+00   2.607332e+00    2.957901e+00           2.591125e+00

# %% [markdown]
# ### Check Class Distribution
# Assess the balance of the target variable `(Attrition)` to determine if we need to handle class imbalance.

# %%
# Check class distribution
data['Attrition'].value_counts()
# Out:
# 0    5957
# 1    2035
# Name: Attrition, dtype: int64

# %%
data['Attrition'].value_counts(normalize=True)*100
# Out:
# 0    74.537037
# 1    25.462963
# Name: Attrition, dtype: float64

# %%
sns.countplot(x=data['Attrition'])
# Out:
# <Axes: xlabel='Attrition', ylabel='count'>

# %% [markdown]
# ### Handling Class Imbalance
# ##### Techniques to Address Class Imbalance
# - Resampling:
#   - Oversampling the minority class using techniques like SMOTE (Synthetic Minority Oversampling Technique).
#   - Undersampling the majority class to balance proportions.
# - Class Weights:
#     - Add weights to the classes in the loss function during model training to penalize misclassifications of the minority class.
# - Evaluation Metrics:
#     - Use metrics like precision, recall, F1-score, or ROC-AUC instead of just accuracy.

# %% [markdown]
# #### Oversampling with SMOTE

# %%
# pip install --upgrade imbalanced-learn

# %%
from imblearn.over_sampling import SMOTE

# %%
# Separate features and target
X = data.drop('Attrition', axis=1)
y = data['Attrition']

# %%
# Apply SMOTE to oversample the minority class
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# %%
y_resampled.value_counts()
# Out:
# 0    5957
# 1    5957
# Name: Attrition, dtype: int64

# %%
y_resampled.value_counts(normalize=True)*100
# Out:
# 0    50.0
# 1    50.0
# Name: Attrition, dtype: float64

# %%
sns.countplot(x=y_resampled)
# Out:
# <Axes: xlabel='Attrition', ylabel='count'>

# %% [markdown]
# ### Final Dataset Ready
# At this stage, the dataset is clean and prepared for the next step in the workflow.

# %%
# Save the cleaned dataset for future use
data.to_csv('cleaned_employee_attrition_balanced.csv', index=False)

# %% [markdown]
# ### Data Splitting
# We’ll split the cleaned dataset into training and testing sets, ensuring the target variable’s distribution is representative in both.

# %%
from sklearn.model_selection import train_test_split

# %%
# Split the dataset (80% training, 20% testing)
X_train, X_test, y_train, y_test = train_test_split(
    X_resampled, y_resampled, test_size=0.2, random_state=42, stratify=y_resampled  # Stratify to maintain class proportions
)

# %%
print("Training set size:", len(X_train))
print("Testing set size:", len(X_test))
# Out:
# Training set size: 9531
# Testing set size: 2383

# %%
# Proportion of Train set distribution
y_train.value_counts(normalize=True)*100
# Out:
# 1    50.005246
# 0    49.994754
# Name: Attrition, dtype: float64

# %%
# Proportion of Test set distribution
y_test.value_counts(normalize=True)*100
# Out:
# 0    50.020982
# 1    49.979018
# Name: Attrition, dtype: float64

# %% [markdown]
# ### Model Selection
# We’ll train multiple classification models to find the best one for predicting attrition. Start with a baseline and expand to more advanced models.

# %% [markdown]
# ### 1. Train a Baseline Model (Logistic Regression)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

# %%
# Train logistic regression model
logreg = LogisticRegression(random_state=42)
# logreg = LogisticRegression(class_weight='balanced', random_state=42)
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
# Predict on the test set
y_pred = logreg.predict(X_test)

# %%
# Evaluate performance
print("Logistic Regression Classification Report:\n")
print(classification_report(y_test, y_pred))
# Out:
# Logistic Regression Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.59      0.57      1192
#            1       0.56      0.52      0.54      1191
#
#     accuracy                           0.56      2383
#    macro avg       0.56      0.56      0.55      2383
# weighted avg       0.56      0.56      0.55      2383

# %% [markdown]
# ### 2. Train Advanced Models (Random Forest)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# Train random forest model
# rf = RandomForestClassifier(class_weight={0:1, 1:3}, random_state=42, n_estimators=100)
rf = RandomForestClassifier(class_weight='balanced', random_state=42, n_estimators=100)
rf.fit(X_train, y_train)
# Predict on the test set
y_pred_rf = rf.predict(X_test)
# Evaluate performance
print("Random Forest Classification Report:\n")
print(classification_report(y_test, y_pred_rf))
# Out:
# Random Forest Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.86      0.82      1192
#            1       0.85      0.77      0.81      1191
#
#     accuracy                           0.82      2383
#    macro avg       0.82      0.82      0.82      2383
# weighted avg       0.82      0.82      0.82      2383

# %% [markdown]
# ### 3. Trying multiple classification models

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
# !pip install xgboost
from xgboost import XGBClassifier

# %%
# Define the models
# class_weights={0:1, 1:3}
class_weights='balanced'
models = {
    'Logistic Regression': LogisticRegression(random_state=42, class_weight=class_weights),
    'Random Forest': RandomForestClassifier(random_state=42, class_weight=class_weights),
    'Support Vector Machine': SVC(random_state=42, class_weight=class_weights),
    'k-Nearest Neighbors': KNeighborsClassifier(),
    'Decision Tree': DecisionTreeClassifier(random_state=42, class_weight=class_weights),
    'Gradient Boosting': GradientBoostingClassifier(random_state=42),
    'AdaBoost': AdaBoostClassifier(random_state=42, algorithm="SAMME"),
    'XGBoost': XGBClassifier(eval_metric='mlogloss')
}

# %%
from sklearn.metrics import classification_report, accuracy_score

results = {}

for model_name, model in models.items():
    print(f"Training {model_name}...")
    # Train the model
    model.fit(X_train, y_train)
    
    # Make predictions
    y_pred = model.predict(X_test)
    
    # Evaluate the model
    accuracy = accuracy_score(y_test, y_pred)
    report = classification_report(y_test, y_pred)
    matrix = confusion_matrix(y_test, y_pred)
    
    # Store results
    results[model_name] = {
        'accuracy': accuracy,
        'classification_report': report,
        'confusion_matrix': matrix
    }
    # print(f"{model_name} Accuracy: {accuracy:.4f}")
    print(f"{model_name} Classification Report:\n{report}")

    sns.heatmap(matrix, annot=True, fmt="g")
    plt.show()
# Out:
# Training Logistic Regression...
# Logistic Regression Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.55      0.59      0.57      1192
#            1       0.56      0.52      0.54      1191
#
#     accuracy                           0.56      2383
#    macro avg       0.56      0.56      0.56      2383
# weighted avg       0.56      0.56      0.56      2383
# Training Random Forest...
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.86      0.82      1192
#            1       0.85      0.77      0.81      1191
#
#     accuracy                           0.82      2383
#    macro avg       0.82      0.82      0.82      2383
# weighted avg       0.82      0.82      0.82      2383
# Training Support Vector Machine...
# Support Vector Machine Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.59      0.51      0.55      1192
#            1       0.57      0.64      0.60      1191
#
#     accuracy                           0.57      2383
#    macro avg       0.58      0.57      0.57      2383
# weighted avg       0.58      0.57      0.57      2383
# Training k-Nearest Neighbors...
# k-Nearest Neighbors Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.53      0.63      1192
#            1       0.64      0.85      0.73      1191
#
#     accuracy                           0.69      2383
#    macro avg       0.71      0.69      0.68      2383
# weighted avg       0.71      0.69      0.68      2383
# Training Decision Tree...
# Decision Tree Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.68      0.70      1192
#            1       0.70      0.74      0.72      1191
#
#     accuracy                           0.71      2383
#    macro avg       0.71      0.71      0.71      2383
# weighted avg       0.71      0.71      0.71      2383
# Training Gradient Boosting...
# Gradient Boosting Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.97      0.82      1192
#            1       0.95      0.62      0.75      1191
#
#     accuracy                           0.79      2383
#    macro avg       0.83      0.79      0.79      2383
# weighted avg       0.83      0.79      0.79      2383
# Training AdaBoost...
# AdaBoost Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.59      0.69      0.64      1192
#            1       0.63      0.52      0.57      1191
#
#     accuracy                           0.61      2383
#    macro avg       0.61      0.61      0.60      2383
# weighted avg       0.61      0.61      0.60      2383
# Training XGBoost...
# XGBoost Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.87      0.80      1192
#            1       0.84      0.70      0.76      1191
#
#     accuracy                           0.78      2383
#    macro avg       0.79      0.78      0.78      2383
# weighted avg       0.79      0.78      0.78      2383

# %% [markdown]
# ### 4. Hyperparameter Tuning
# We’ll use grid search to optimize hyperparameters for the Random Forest model.

# %%
from sklearn.model_selection import GridSearchCV

# %%
# Define parameter grid
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# %%
grid_search = GridSearchCV(
    RandomForestClassifier(class_weight='balanced', random_state=42),
    param_grid, cv=5, scoring='f1', n_jobs=-1
)

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=RandomForestClassifier(class_weight='balanced',
#                                               random_state=42),
#              n_jobs=-1,
#              param_grid={'max_depth': [None, 10, 20, 30],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 200]},
#              scoring='f1')

# %%
# Best parameters
print("Best Hyperparameters:", grid_search.best_params_)
# Out:
# Best Hyperparameters: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}

# %%
# Train best model
best_rf = grid_search.best_estimator_

# %%
# Predict on the test set
y_pred_best_rf = best_rf.predict(X_test)

# %%
# Evaluate performance
print("Tuned Random Forest Classification Report:\n")
print(classification_report(y_test, y_pred_best_rf))
# Out:
# Tuned Random Forest Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.87      0.83      1192
#            1       0.86      0.77      0.81      1191
#
#     accuracy                           0.82      2383
#    macro avg       0.83      0.82      0.82      2383
# weighted avg       0.83      0.82      0.82      2383

# %% [markdown]
# ### Model Evaluation
# We’ll perform a detailed evaluation using metrics like precision, recall, F1-score, and AUC-ROC. Confusion matrices and AUC curves will help visualize performance.

# %% [markdown]
# #### Confusion Matrix
# Confusion matrix to visualize misclassifications.

# %%
from sklearn.metrics import confusion_matrix

# %%
conf_matrix = confusion_matrix(y_test, y_pred_best_rf)

# %%
# Plot the confusion matrix
plt.figure(figsize=(8, 4))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['No', 'Yes'], yticklabels=['No', 'Yes'])
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# #### ROC Curve and AUC Score
# ROC-AUC to evaluate the model's ability to distinguish between classes.

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# %%
# Compute probabilities for ROC
y_probs = best_rf.predict_proba(X_test)[:, 1]  # Probabilities for the positive class

# %%
# ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_probs)
auc_score = roc_auc_score(y_test, y_probs)

# %%
# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f"AUC = {auc_score:.2f}")
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
plt.title("ROC Curve")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### 6. Using AutoML to select best model

# %% [markdown]
# #### Using PyCaret
# PyCaret is a low-code library for automating machine learning workflows.

# %%
# pip install pycaret

# %%
# pip install scikit-learn==1.4

# %%
from pycaret.classification import *

# %%
# Combine features and target into one DataFrame
# df = pd.concat([X, y], axis=1)
df = pd.concat([X_resampled, y_resampled], axis=1)

# %%
df.head(2)
# Out:
#         Age  Gender  MonthlyIncome  YearsAtCompany  OverTime  JobSatisfaction  \
# 0  0.479168       1      -1.301722        0.503833         0              2.0
# 1 -0.221194       1      -0.778837       -0.232387         0              2.0
#
#    WorkLifeBalance  TrainingTimesLastYear  Department_HR  Department_IT  \
# 0                3               1.900458              1              0
# 1                2               0.519124              1              0
#
#    Department_Operations  Department_Sales  Attrition
# 0                      0                 0          0
# 1                      0                 0          0

# %%
# Initialize PyCaret
clf_setup = setup(
    data=df, 
    target='Attrition', 
    normalize=True,
    session_id=42,
    # use_gpu=True,
)
# Out:
# <style type="text/css">
# #T_81be0_row8_col1, #T_81be0_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_81be0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_81be0_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_81be0_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_81be0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_81be0_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_81be0_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_81be0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_81be0_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_81be0_row1_col1" class="data row1 col1" >Attrition</td>
#     </tr>
#     <tr>
#       <th id="T_81be0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_81be0_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_81be0_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_81be0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_81be0_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_81be0_row3_col1" class="data row3 col1" >(11914, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_81be0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_81be0_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_81be0_row4_col1" class="data row4 col1" >(11914, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_81be0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_81be0_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_81be0_row5_col1" class="data row5 col1" >(8339, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_81be0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_81be0_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_81be0_row6_col1" class="data row6 col1" >(3575, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_81be0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_81be0_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_81be0_row7_col1" class="data row7 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_81be0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_81be0_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_81be0_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_81be0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_81be0_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_81be0_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_81be0_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_81be0_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_81be0_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_81be0_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_81be0_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_81be0_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_81be0_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_81be0_row12_col0" class="data row12 col0" >Normalize</td>
#       <td id="T_81be0_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_81be0_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_81be0_row13_col0" class="data row13 col0" >Normalize method</td>
#       <td id="T_81be0_row13_col1" class="data row13 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_81be0_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_81be0_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_81be0_row14_col1" class="data row14 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_81be0_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_81be0_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_81be0_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_81be0_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_81be0_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_81be0_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_81be0_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_81be0_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_81be0_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_81be0_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_81be0_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_81be0_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_81be0_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_81be0_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_81be0_row19_col1" class="data row19 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_81be0_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_81be0_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_81be0_row20_col1" class="data row20 col1" >aa54</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Compare models and select the best one
best_model = compare_models(cross_validation=False, sort="f1", )
# Out:
# <style type="text/css">
# #T_106b2 th {
#   text-align: left;
# }
# #T_106b2_row0_col0, #T_106b2_row0_col3, #T_106b2_row0_col4, #T_106b2_row0_col7, #T_106b2_row1_col0, #T_106b2_row1_col1, #T_106b2_row1_col2, #T_106b2_row1_col3, #T_106b2_row1_col4, #T_106b2_row1_col5, #T_106b2_row1_col6, #T_106b2_row1_col7, #T_106b2_row2_col0, #T_106b2_row2_col1, #T_106b2_row2_col2, #T_106b2_row2_col3, #T_106b2_row2_col4, #T_106b2_row2_col5, #T_106b2_row2_col6, #T_106b2_row3_col0, #T_106b2_row3_col1, #T_106b2_row3_col2, #T_106b2_row3_col3, #T_106b2_row3_col4, #T_106b2_row3_col5, #T_106b2_row3_col6, #T_106b2_row3_col7, #T_106b2_row4_col0, #T_106b2_row4_col1, #T_106b2_row4_col2, #T_106b2_row4_col3, #T_106b2_row4_col5, #T_106b2_row4_col6, #T_106b2_row4_col7, #T_106b2_row5_col0, #T_106b2_row5_col1, #T_106b2_row5_col2, #T_106b2_row5_col3, #T_106b2_row5_col4, #T_106b2_row5_col5, #T_106b2_row5_col6, #T_106b2_row5_col7, #T_106b2_row6_col0, #T_106b2_row6_col1, #T_106b2_row6_col2, #T_106b2_row6_col3, #T_106b2_row6_col4, #T_106b2_row6_col5, #T_106b2_row6_col6, #T_106b2_row6_col7, #T_106b2_row7_col0, #T_106b2_row7_col1, #T_106b2_row7_col2, #T_106b2_row7_col4, #T_106b2_row7_col5, #T_106b2_row7_col6, #T_106b2_row7_col7, #T_106b2_row8_col0, #T_106b2_row8_col1, #T_106b2_row8_col2, #T_106b2_row8_col3, #T_106b2_row8_col4, #T_106b2_row8_col5, #T_106b2_row8_col6, #T_106b2_row8_col7, #T_106b2_row9_col0, #T_106b2_row9_col1, #T_106b2_row9_col2, #T_106b2_row9_col3, #T_106b2_row9_col4, #T_106b2_row9_col5, #T_106b2_row9_col6, #T_106b2_row9_col7, #T_106b2_row10_col0, #T_106b2_row10_col1, #T_106b2_row10_col2, #T_106b2_row10_col3, #T_106b2_row10_col4, #T_106b2_row10_col5, #T_106b2_row10_col6, #T_106b2_row10_col7, #T_106b2_row11_col0, #T_106b2_row11_col1, #T_106b2_row11_col2, #T_106b2_row11_col3, #T_106b2_row11_col4, #T_106b2_row11_col5, #T_106b2_row11_col6, #T_106b2_row11_col7, #T_106b2_row12_col0, #T_106b2_row12_col1, #T_106b2_row12_col2, #T_106b2_row12_col3, #T_106b2_row12_col4, #T_106b2_row12_col5, #T_106b2_row12_col6, #T_106b2_row12_col7, #T_106b2_row13_col0, #T_106b2_row13_col1, #T_106b2_row13_col2, #T_106b2_row13_col3, #T_106b2_row13_col4, #T_106b2_row13_col5, #T_106b2_row13_col6, #T_106b2_row13_col7, #T_106b2_row14_col0, #T_106b2_row14_col1, #T_106b2_row14_col2, #T_106b2_row14_col3, #T_106b2_row14_col4, #T_106b2_row14_col5, #T_106b2_row14_col6, #T_106b2_row14_col7 {
#   text-align: left;
# }
# #T_106b2_row0_col1, #T_106b2_row0_col2, #T_106b2_row0_col5, #T_106b2_row0_col6, #T_106b2_row2_col7, #T_106b2_row4_col4, #T_106b2_row7_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_106b2_row0_col8, #T_106b2_row1_col8, #T_106b2_row2_col8, #T_106b2_row3_col8, #T_106b2_row4_col8, #T_106b2_row5_col8, #T_106b2_row8_col8, #T_106b2_row11_col8, #T_106b2_row12_col8, #T_106b2_row13_col8, #T_106b2_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_106b2_row6_col8, #T_106b2_row7_col8, #T_106b2_row9_col8, #T_106b2_row10_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_106b2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_106b2_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_106b2_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_106b2_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_106b2_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_106b2_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_106b2_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_106b2_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_106b2_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_106b2_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_106b2_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_106b2_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_106b2_row0_col1" class="data row0 col1" >0.8134</td>
#       <td id="T_106b2_row0_col2" class="data row0 col2" >0.8775</td>
#       <td id="T_106b2_row0_col3" class="data row0 col3" >0.7750</td>
#       <td id="T_106b2_row0_col4" class="data row0 col4" >0.8394</td>
#       <td id="T_106b2_row0_col5" class="data row0 col5" >0.8059</td>
#       <td id="T_106b2_row0_col6" class="data row0 col6" >0.6268</td>
#       <td id="T_106b2_row0_col7" class="data row0 col7" >0.6287</td>
#       <td id="T_106b2_row0_col8" class="data row0 col8" >0.2200</td>
#     </tr>
#     <tr>
#       <th id="T_106b2_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_106b2_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_106b2_row1_col1" class="data row1 col1" >0.7955</td>
#       <td id="T_106b2_row1_col2" class="data row1 col2" >0.8740</td>
#       <td id="T_106b2_row1_col3" class="data row1 col3" >0.7969</td>
#       <td id="T_106b2_row1_col4" class="data row1 col4" >0.7946</td>
#       <td id="T_106b2_row1_col5" class="data row1 col5" >0.7958</td>
#       <td id="T_106b2_row1_col6" class="data row1 col6" >0.5910</td>
#       <td id="T_106b2_row1_col7" class="data row1 col7" >0.5911</td>
#       <td id="T_106b2_row1_col8" class="data row1 col8" >0.1500</td>
#     </tr>
#     <tr>
#       <th id="T_106b2_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_106b2_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_106b2_row2_col1" class="data row2 col1" >0.8129</td>
#       <td id="T_106b2_row2_col2" class="data row2 col2" >0.8474</td>
#       <td id="T_106b2_row2_col3" class="data row2 col3" >0.6788</td>
#       <td id="T_106b2_row2_col4" class="data row2 col4" >0.9274</td>
#       <td id="T_106b2_row2_col5" class="data row2 col5" >0.7838</td>
#       <td id="T_106b2_row2_col6" class="data row2 col6" >0.6257</td>
#       <td id="T_106b2_row2_col7" class="data row2 col7" >0.6495</td>
#       <td id="T_106b2_row2_col8" class="data row2 col8" >0.3000</td>
#     </tr>
#     <tr>
#       <th id="T_106b2_level0_row3" class="row_heading level0 row3" >xgboost</th>
#       <td id="T_106b2_row3_col0" class="data row3 col0" >Extreme Gradient Boosting</td>
#       <td id="T_106b2_row3_col1" class="data row3 col1" >0.7933</td>
#       <td id="T_106b2_row3_col2" class="data row3 col2" >0.8426</td>
#       <td id="T_106b2_row3_col3" class="data row3 col3" >0.6973</td>
#       <td id="T_106b2_row3_col4" class="data row3 col4" >0.8629</td>
#       <td id="T_106b2_row3_col5" class="data row3 col5" >0.7713</td>
#       <td id="T_106b2_row3_col6" class="data row3 col6" >0.5866</td>
#       <td id="T_106b2_row3_col7" class="data row3 col7" >0.5977</td>
#       <td id="T_106b2_row3_col8" class="data row3 col8" >0.1900</td>
#     </tr>
#     <tr>
#       <th id="T_106b2_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_106b2_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_106b2_row4_col1" class="data row4 col1" >0.7846</td>
#       <td id="T_106b2_row4_col2" class="data row4 col2" >0.8237</td>
#       <td id="T_106b2_row4_col3" class="data row4 col3" >0.5965</td>
#       <td id="T_106b2_row4_col4" class="data row4 col4" >0.9561</td>
#       <td id="T_106b2_row4_col5" class="data row4 col5" >0.7347</td>
#       <td id="T_106b2_row4_col6" class="data row4 col6" >0.5692</td>
#       <td id="T_106b2_row4_col7" class="data row4 col7" >0.6143</td>
#       <td id="T_106b2_row4_col8" class="data row4 col8" >0.7000</td>
#     </tr>
#     <tr>
#       <th id="T_106b2_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_106b2_row5_col0" class="data row5 col0" >Decision Tree Classifier</td>
#       <td id="T_106b2_row5_col1" class="data row5 col1" >0.7071</td>
#       <td id="T_106b2_row5_col2" class="data row5 col2" >0.7071</td>
#       <td id="T_106b2_row5_col3" class="data row5 col3" >0.7314</td>
#       <td id="T_106b2_row5_col4" class="data row5 col4" >0.6974</td>
#       <td
# Processing:   0%|          | 0/65 [00:00<?, ?it/s]

# %%
# Display the best model
print(best_model)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        monotonic_cst=None, n_estimators=100, n_jobs=-1,
#                        oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
# Fine-tune the best model
tuned_model = tune_model(best_model, optimize="f1", fold=5)
# Out:
# <style type="text/css">
# #T_bb596_row5_col0, #T_bb596_row5_col1, #T_bb596_row5_col2, #T_bb596_row5_col3, #T_bb596_row5_col4, #T_bb596_row5_col5, #T_bb596_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_bb596">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bb596_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_bb596_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_bb596_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_bb596_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_bb596_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_bb596_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_bb596_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb596_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bb596_row0_col0" class="data row0 col0" >0.7296</td>
#       <td id="T_bb596_row0_col1" class="data row0 col1" >0.8003</td>
#       <td id="T_bb596_row0_col2" class="data row0 col2" >0.7158</td>
#       <td id="T_bb596_row0_col3" class="data row0 col3" >0.7361</td>
#       <td id="T_bb596_row0_col4" class="data row0 col4" >0.7258</td>
#       <td id="T_bb596_row0_col5" class="data row0 col5" >0.4592</td>
#       <td id="T_bb596_row0_col6" class="data row0 col6" >0.4594</td>
#     </tr>
#     <tr>
#       <th id="T_bb596_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bb596_row1_col0" class="data row1 col0" >0.7146</td>
#       <td id="T_bb596_row1_col1" class="data row1 col1" >0.7947</td>
#       <td id="T_bb596_row1_col2" class="data row1 col2" >0.7110</td>
#       <td id="T_bb596_row1_col3" class="data row1 col3" >0.7162</td>
#       <td id="T_bb596_row1_col4" class="data row1 col4" >0.7136</td>
#       <td id="T_bb596_row1_col5" class="data row1 col5" >0.4293</td>
#       <td id="T_bb596_row1_col6" class="data row1 col6" >0.4293</td>
#     </tr>
#     <tr>
#       <th id="T_bb596_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bb596_row2_col0" class="data row2 col0" >0.7086</td>
#       <td id="T_bb596_row2_col1" class="data row2 col1" >0.7784</td>
#       <td id="T_bb596_row2_col2" class="data row2 col2" >0.7206</td>
#       <td id="T_bb596_row2_col3" class="data row2 col3" >0.7037</td>
#       <td id="T_bb596_row2_col4" class="data row2 col4" >0.7121</td>
#       <td id="T_bb596_row2_col5" class="data row2 col5" >0.4173</td>
#       <td id="T_bb596_row2_col6" class="data row2 col6" >0.4174</td>
#     </tr>
#     <tr>
#       <th id="T_bb596_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bb596_row3_col0" class="data row3 col0" >0.7320</td>
#       <td id="T_bb596_row3_col1" class="data row3 col1" >0.7999</td>
#       <td id="T_bb596_row3_col2" class="data row3 col2" >0.7050</td>
#       <td id="T_bb596_row3_col3" class="data row3 col3" >0.7452</td>
#       <td id="T_bb596_row3_col4" class="data row3 col4" >0.7246</td>
#       <td id="T_bb596_row3_col5" class="data row3 col5" >0.4640</td>
#       <td id="T_bb596_row3_col6" class="data row3 col6" >0.4647</td>
#     </tr>
#     <tr>
#       <th id="T_bb596_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bb596_row4_col0" class="data row4 col0" >0.7157</td>
#       <td id="T_bb596_row4_col1" class="data row4 col1" >0.7909</td>
#       <td id="T_bb596_row4_col2" class="data row4 col2" >0.7494</td>
#       <td id="T_bb596_row4_col3" class="data row4 col3" >0.7022</td>
#       <td id="T_bb596_row4_col4" class="data row4 col4" >0.7251</td>
#       <td id="T_bb596_row4_col5" class="data row4 col5" >0.4313</td>
#       <td id="T_bb596_row4_col6" class="data row4 col6" >0.4323</td>
#     </tr>
#     <tr>
#       <th id="T_bb596_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_bb596_row5_col0" class="data row5 col0" >0.7201</td>
#       <td id="T_bb596_row5_col1" class="data row5 col1" >0.7929</td>
#       <td id="T_bb596_row5_col2" class="data row5 col2" >0.7204</td>
#       <td id="T_bb596_row5_col3" class="data row5 col3" >0.7207</td>
#       <td id="T_bb596_row5_col4" class="data row5 col4" >0.7202</td>
#       <td id="T_bb596_row5_col5" class="data row5 col5" >0.4402</td>
#       <td id="T_bb596_row5_col6" class="data row5 col6" >0.4406</td>
#     </tr>
#     <tr>
#       <th id="T_bb596_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_bb596_row6_col0" class="data row6 col0" >0.0091</td>
#       <td id="T_bb596_row6_col1" class="data row6 col1" >0.0080</td>
#       <td id="T_bb596_row6_col2" class="data row6 col2" >0.0154</td>
#       <td id="T_bb596_row6_col3" class="data row6 col3" >0.0173</td>
#       <td id="T_bb596_row6_col4" class="data row6 col4" >0.0061</td>
#       <td id="T_bb596_row6_col5" class="data row6 col5" >0.0182</td>
#       <td id="T_bb596_row6_col6" class="data row6 col6" >0.0183</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
# Evaluate the tuned model
evaluate_model(tuned_model, fold=5)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# Finalize the model
final_model = finalize_model(tuned_model)

# %%
# Predict on the test set
predictions = predict_model(final_model, data=X_test)

# %% [markdown]
# #### Saving the model

# %%
save_model(final_model, 'final_model_attrition_prediction')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Age', 'Gender', 'MonthlyIncome',
#                                               'YearsAtCompany', 'OverTime',
#                                               'JobSatisfaction',
#                                               'WorkLifeBalance',
#                                               'TrainingTimesLastYear',
#                                               'Department_HR', 'Department_IT',
#                                               'Department_Operations',
#                                               'Department_Sales'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                co...
#                   RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                          class_weight=None, criterion='gini',
#                                          max_depth=None, max_features='sqrt',
#                                          max_leaf_nodes=None, max_samples=None,
#                                          min_impurity_decrease=0.0,
#                                          min_samples_leaf=1, min_samples_split=2,
#                                          min_weight_fraction_leaf=0.0,
#                                          monotonic_cst=None, n_estimators=100,
#                                          n_jobs=-1, oob_score=False,
#                                          random_state=42, verbose=0,
#                                          warm_start=False))],
#           verbose=False),
#  'final_model_attrition_prediction.pkl')

# %% [markdown]
# #### Loading the model

# %%
loaded_model = load_model('final_model_attrition_prediction')
# Out:
# Transformation Pipeline and Model Successfully Loaded
